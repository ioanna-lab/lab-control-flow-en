# %% [markdown]
# ## Words

# %%
words = ['play', 'filling', 'bar', 'theatre', 'easygoing', 'date', 'lead', 'that', 'story',  'island']

# %% [markdown]
# **Print every word in upper case**

# %%
# making the words in upper letter by using the function .upper()
words_upper = [word.upper() for word in words]
# printing the words
print(words_upper)

# %% [markdown]
# **Create a new list containing only words with 5 or more letters**

# %%
# nested list creation 
words_above_5 = [word for word in words if len(word) >= 5]
print(words_above_5)

# %% [markdown]
# **Print the first word starting with "t"**

# %%
# we need to check at the starting of the word.
for word in words:
  if word.startswith('t') or word.startswith('T'):
    print(word)
    break

# %% [markdown]
# ## Numbers

# %% [markdown]
# **Create a list containing the square of every number from 1 to 10**

# %%
# list initialization to hold the results
list_square = []
for i in range(1,11):
  list_square.append(i**2)

print(list_square)

# %% [markdown]
# **Print a list containing the square of every odd number from 1 to 10**

# %%
#initialise the list
list_square = []
#for loop for 1 to 10 with nested logic for the odd numbers and then their square
for i in range(1,11):
  if i%2 == 0:
    continue
  else:
    list_square.append(i**2)

print(list_square)

# %% [markdown]
# **Create a list with the squares of all multiples of 8 below 1000**

# %%
# two lists, one for the multiplier that their square will not exceed the 1000 and one more for the multiplieers that will survive this criterion
list_square_multiples_8 = []
list_of_multiples = []
for i in range(1,1000):
  if i%8 == 0 and i**2 <1000:
    list_of_multiples.append(i)
    list_square_multiples_8.append(i**2)    


print(list_of_multiples, list_square_multiples_8)

# %% [markdown]
# ## People

# %%
people = [
    {
        "name": "Juan",
        "age": 34,
        "n_kids": 2
    },
    {
        "name": "Pepe",
        "age": 27,
        "n_kids": 0
    },
    {
        "name": "Sonia",
        "age": 41,
        "n_kids": 1
    },
    {
        "name": "Lucía",
        "age": 22,
        "n_kids": 2
    },
    {
        "name": "Leo",
        "age": 55,
        "n_kids": 5
    }
]

# %% [markdown]
# **How many people are there?**

# %%
length_people = len(people)
print(length_people)

# %% [markdown]
# **How many people have kids**?

# %%
# your code here
kids = 0
for person in people:
  if person['n_kids'] > 0:
    kids += 1
print(kids)

# %% [markdown]
# **How many kids do they have in total?**

# %%
total_kids = 0
for person in people:
  total_kids += person['n_kids']
  
print(total_kids)

# %% [markdown]
# **In a year's time, names ending with "a" will have an extra kid. Create a list of dictionaries with people's info in a year's time**

# %%
# create a new list to hold only the updated people
new_list = []
for person in people:
  if person['name'].endswith('a'): #check end letter
    person['n_kids'] += 1 #increase the number in case the condition is met
    new_list.append(person) #hold a new list to use it for future cases.
    
#print the entire dictionary
print(people)
#print only the updated people
print(new_list)
